# %%
import numpy
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.ticker import MaxNLocator
tickS = 21
label = 22
tittle = 23

# %%
p13r=1091.261
p14r=640.393
p15r=876.792
pol13dpNTlabel = [i for i in range(50,5000, 100)]
pol13dpNTvalues = [40.96, 92.69, 40.27, 32.34, 48.74, 
                   115.466, 53.66, 37.04, 61.06, 142.98, 123.714, 
                  92.62, 80.78, 83.91, 72.97, 44.18, 35.76, 56.95, 
                  113, 82.25, 59.45, 55.31, 35.17, 78.50, 71.36, 72.36, 
                  82.25, 58.45, 68.15, 48.315, 68.84, 34.18, 95.58, 12.5, 
                  106.328, 144.849, 130, 65, 63, 56, 73, 109, 83, 
                  69.5, 63.59, 60, 27.7, 25, 25, 28]
pol14dpNTlabel = [i for i in range(50,5000, 100)]
pol14dpNTvalues = [285.8, 138.8, 111.43, 113.62, 66.01, 115.86, 341.906, 
                  506.999, 442, 365, 251, 47, 161, 602, 315, 78, 199, 85, 
                   138, 78.0, 292, 454, 382, 257, 100, 
                   213, 177, 109, 124, 168, 412, 266, 341, 224, 418, 366, 
                   157, 100, 53, 140, 243, 232, 214, 212, 309, 181, 155, 
                   171, 168, 79]
pol15dpNTlabel = [i for i in range(50,5000, 100)]
pol15dpNTvalues = [157, 162, 58, 76, 124, 241, 87, 179, 174, 70, 65, 259, 
                  201, 150, 35, 106, 243, 217, 38, 29, 67, 255, 187, 185, 307, 
                  222, 100, 84, 22, 29, 52, 389, 112, 461, 747, 301, 298, 
                   389, 347, 233, 184, 188, 309, 145, 79, 73, 54, 58, 89, 88 ]

# %%
print(len(pol13dpNTlabel), len(pol13dpNTvalues))
print(len(pol14dpNTlabel), len(pol14dpNTvalues))
print(len(pol15dpNTlabel), len(pol15dpNTvalues))
# Out:
# 50 50
# 50 50
# 50 50

# %%
fig, ax1 = plt.subplots(1, 1, figsize=(18, 7))
ax1.plot(pol13dpNTlabel, pol13dpNTvalues, 'r:', markersize=11, linewidth=2, marker='o')
ax1.plot(pol14dpNTlabel, pol14dpNTvalues, 'g:', markersize=11, linewidth=2, marker='o') 
ax1.plot(pol15dpNTlabel, pol15dpNTvalues, 'b:', markersize=11, linewidth=2, marker='o') 

ax1.set_xlabel('number of generated task with BFS for threads', fontsize=label)
ax1.set_ylabel('time (s)', fontsize=label)
#ax1.set_title('pol13', fontsize=tittle)

for tick in ax1.xaxis.get_major_ticks():
    tick.label.set_fontsize(tickS) 
for tick in ax1.yaxis.get_major_ticks():
    tick.label.set_fontsize(tickS)

ax1.grid()
plt.legend(['pol13', 'pol14', 'pol15'], fontsize=label)

fig.savefig("nN20T.png")
plt.show()

# %%
pol13dpNTlabel = [34, 41, 55, 62]
pol13dpNTvalues = [5.9, 6.0, 6.2, 6.2]
pol15dpNTlabel = [34, 41, 55, 62]
pol15dpNTvalues = [103, 152, 211, 212]

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(21, 9))
ax1.plot(pol13dpNTlabel, pol13dpNTvalues, 'r:', markersize=11, linewidth=2, marker='o')
ax2.plot(pol15dpNTlabel, pol15dpNTvalues, 'b:', markersize=11, linewidth=2, marker='o') 

ax1.set_xlabel('number of generated task with BFS for processes', fontsize=label)
ax1.set_ylabel('time (s)', fontsize=label)
ax1.set_title('pol13', fontsize=tittle)
ax2.set_xlabel('number of generated task with BFS for processes', fontsize=label)
ax2.set_ylabel('time (s)', fontsize=label)
ax2.set_title('pol15', fontsize=tittle)
for tick in ax1.xaxis.get_major_ticks():
    tick.label.set_fontsize(tickS) 
for tick in ax1.yaxis.get_major_ticks():
    tick.label.set_fontsize(tickS)
for tick in ax2.xaxis.get_major_ticks():
    tick.label.set_fontsize(tickS) 
for tick in ax2.yaxis.get_major_ticks():
    tick.label.set_fontsize(tickS)
ax1.grid()
ax2.grid()

fig.savefig("nNP60T.png")
plt.show()

# %%
pol13dpNTlabel = [1, 2, 4, 8, 12, 16, 20]
pol13dpNTvalues = [p13r, 834.342, 523.887, 163.81, 73.52, 89.92, 87.9]
pol14dpNTlabel = [1, 2, 4, 8, 12, 16, 20]
pol14dpNTvalues = [p14r, 301.545, 294.993, 97.41, 105.504, 115.315, 103.599]
pol15dpNTlabel = [1, 2, 4, 8, 12, 16, 20]
pol15dpNTvalues = [p15r, 470.528, 529.601, 794.188, 691.391, 29.52, 28.699]

# %%
fig, ax1 = plt.subplots(1, 1, figsize=(15, 6))
ax1.plot(pol13dpNTlabel, pol13dpNTvalues, 'r:', markersize=11, linewidth=2, marker='o')
ax1.plot(pol14dpNTlabel, pol14dpNTvalues, 'g:', markersize=11, linewidth=2, marker='o') 
ax1.plot(pol15dpNTlabel, pol15dpNTvalues, 'b:', markersize=11, linewidth=2, marker='o') 
ax1.xaxis.set_major_locator(MaxNLocator(integer=True))

ax1.set_xlabel('number of threads on one procesor', fontsize=label)
ax1.set_ylabel('time (s)', fontsize=label)
#ax1.set_title('pol13', fontsize=tittle)

for tick in ax1.xaxis.get_major_ticks():
    tick.label.set_fontsize(tickS) 
for tick in ax1.yaxis.get_major_ticks():
    tick.label.set_fontsize(tickS)

ax1.grid()
plt.legend(['pol13', 'pol14', 'pol15'], fontsize=label)

fig.savefig("nTdp.png")
plt.show()

# %%
p13efektivity = [p13r/(pol13dpNTlabel[i]*pol13dpNTvalues[i])for i, j in enumerate(pol13dpNTlabel)]
p14efektivity = [p14r/(pol14dpNTlabel[i]*pol14dpNTvalues[i])for i, j in enumerate(pol14dpNTlabel)]
p15efektivity = [p15r/(pol15dpNTlabel[i]*pol15dpNTvalues[i])for i, j in enumerate(pol15dpNTlabel)]
    
p13parfast = [p13r/pol13dpNTvalues[i] for i, j in enumerate(pol13dpNTlabel)]
p14parfast = [p14r/pol14dpNTvalues[i] for i, j in enumerate(pol14dpNTlabel)]
p15parfast = [p15r/pol15dpNTvalues[i] for i, j in enumerate(pol15dpNTlabel)]

# %%
fig, ax = plt.subplots(figsize=(18, 6))
ax.plot(pol13dpNTlabel, p13parfast, 'r:', markersize=11, linewidth=2, marker='o')
ax.plot(pol14dpNTlabel, p14parfast, 'g:', markersize=11, linewidth=2, marker='o') 
ax.plot(pol15dpNTlabel, p15parfast, 'b:', markersize=11, linewidth=2, marker='o') 
ax.plot([0, 25],[0, 25],'k--')
ax.set_xlabel('number of cores on one procesor', fontsize=label)
ax.set_ylabel('parallel acceleration', fontsize=label)
#ax.set_title('parallel speed up', fontsize=tittle)
for tick in ax.xaxis.get_major_ticks():
    tick.label.set_fontsize(tickS) 
for tick in ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(tickS)
ax.grid()
plt.legend(['pol13', 'pol14', 'pol15', 'linear'], fontsize=label)


fig.savefig("parralelFastdp.png")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(18, 10))
ax.plot(pol13dpNTlabel, p13efektivity, 'r:', markersize=11, linewidth=2, marker='o')
ax.plot(pol14dpNTlabel, p14efektivity, 'g:', markersize=11, linewidth=2, marker='o') 
ax.plot(pol15dpNTlabel, p15efektivity, 'b:', markersize=11, linewidth=2, marker='o') 
ax.set_xlabel('number of cores', fontsize=label)
ax.set_ylabel('effectivity', fontsize=label)
#ax.set_title('parallel effectivity', fontsize=tittle)
for tick in ax.xaxis.get_major_ticks():
    tick.label.set_fontsize(tickS) 
for tick in ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(tickS)
ax.grid()
plt.legend(['pol13', 'pol14', 'pol15'], fontsize=label)


fig.savefig("parralelEfectivitydp.png")
plt.show()

# %% [markdown]
# # 2 workers

# %%
pol13dpNTlabel = [1, 4, 8, 16, 24, 32, 40]
pol13dpNTvalues = [p13r, 332, 230, 147, 258, 200, 135]
pol14dpNTlabel = [1, 4, 8, 16, 24, 32, 40]
pol14dpNTvalues = [p14r, 276, 380, 843, 812, 689, 302]
pol15dpNTlabel = [1, 4, 8, 16, 24, 32, 40]
pol15dpNTvalues = [p15r, 850, 662, 457, 52, 71, 88]

# %%
fig, ax1 = plt.subplots(1, 1, figsize=(15, 6))
ax1.plot(pol13dpNTlabel, pol13dpNTvalues, 'r:', markersize=11, linewidth=2, marker='o')
ax1.plot(pol14dpNTlabel, pol14dpNTvalues, 'g:', markersize=11, linewidth=2, marker='o') 
ax1.plot(pol15dpNTlabel, pol15dpNTvalues, 'b:', markersize=11, linewidth=2, marker='o') 

ax1.set_xlabel('number of cores', fontsize=label)
ax1.set_ylabel('time (s)', fontsize=label)
#ax1.set_title('pol13', fontsize=tittle)

for tick in ax1.xaxis.get_major_ticks():
    tick.label.set_fontsize(tickS) 
for tick in ax1.yaxis.get_major_ticks():
    tick.label.set_fontsize(tickS)
plt.legend(['pol13', 'pol14', 'pol15'], fontsize=label)
ax1.grid()


fig.savefig("nTmpi2.png")
plt.show()

# %%
p13efektivity = [p13r/(pol13dpNTlabel[i]*pol13dpNTvalues[i])for i, j in enumerate(pol13dpNTlabel)]
p14efektivity = [p14r/(pol14dpNTlabel[i]*pol14dpNTvalues[i])for i, j in enumerate(pol14dpNTlabel)]
p15efektivity = [p15r/(pol15dpNTlabel[i]*pol15dpNTvalues[i])for i, j in enumerate(pol15dpNTlabel)]
    
p13parfast = [p13r/pol13dpNTvalues[i] for i, j in enumerate(pol13dpNTlabel)]
p14parfast = [p14r/pol14dpNTvalues[i] for i, j in enumerate(pol14dpNTlabel)]
p15parfast = [p15r/pol15dpNTvalues[i] for i, j in enumerate(pol15dpNTlabel)]

# %%
fig, ax = plt.subplots(figsize=(18, 10))
ax.plot(pol13dpNTlabel, p13parfast, 'r:', markersize=11, linewidth=2, marker='o')
ax.plot(pol14dpNTlabel, p14parfast, 'g:', markersize=11, linewidth=2, marker='o') 
ax.plot(pol15dpNTlabel, p15parfast, 'b:', markersize=11, linewidth=2, marker='o') 
ax.plot([0, 25],[0, 25],'k--')
ax.set_xlabel('number of cores', fontsize=label)
ax.set_ylabel('parallel acceleration', fontsize=label)
#ax.set_title('parallel speed up 2 nodes', fontsize=tittle)
for tick in ax.xaxis.get_major_ticks():
    tick.label.set_fontsize(tickS) 
for tick in ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(tickS)
ax.grid()
plt.legend(['pol13', 'pol14', 'pol15', 'linear'], fontsize=label)


fig.savefig("parralelFastmpi2.png")
plt.show()

# %% [markdown]
# # 3 workers

# %%
pol13dpNTlabel = [1, 6, 12, 24, 36, 48, 60]
pol13dpNTvalues = [p13r, 900, 602, 74, 7.2, 225, 5.45]
pol14dpNTlabel = [1, 6, 12, 24, 36, 48, 60]
pol14dpNTvalues = [p14r, 801, 625, 350, 160, 97,50]
pol15dpNTlabel = [1, 6, 12, 24, 36, 48, 60]
pol15dpNTvalues = [p15r, 433, 125, 156, 42, 35, 49]

# %%
fig, ax1 = plt.subplots(1, 1, figsize=(15, 6))
ax1.plot(pol13dpNTlabel, pol13dpNTvalues, 'r:', markersize=11, linewidth=2, marker='o')
ax1.plot(pol14dpNTlabel, pol14dpNTvalues, 'g:', markersize=11, linewidth=2, marker='o') 
ax1.plot(pol15dpNTlabel, pol15dpNTvalues, 'b:', markersize=11, linewidth=2, marker='o') 

ax1.set_xlabel('number of cores', fontsize=label)
ax1.set_ylabel('time (s)', fontsize=label)
#ax1.set_title('pol13', fontsize=tittle)
ax1.set_xlabel('number of cores', fontsize=label)
ax1.set_ylabel('time (s)', fontsize=label)
#ax1.set_title('pol14', fontsize=tittle)
ax1.set_xlabel('number of cores', fontsize=label)
ax1.set_ylabel('time (s)', fontsize=label)
#ax1.set_title('pol15', fontsize=tittle)
ax1.grid()
plt.legend(['pol13', 'pol14', 'pol15'], fontsize=label)
for tick in ax1.xaxis.get_major_ticks():
    tick.label.set_fontsize(tickS) 
for tick in ax1.yaxis.get_major_ticks():
    tick.label.set_fontsize(tickS)


fig.savefig("nTmpi3.png")
plt.show()

# %%
p13efektivity = [p13r/(pol13dpNTlabel[i]*pol13dpNTvalues[i])for i, j in enumerate(pol13dpNTlabel)]
p14efektivity = [p14r/(pol14dpNTlabel[i]*pol14dpNTvalues[i])for i, j in enumerate(pol14dpNTlabel)]
p15efektivity = [p15r/(pol15dpNTlabel[i]*pol15dpNTvalues[i])for i, j in enumerate(pol15dpNTlabel)]
    
p13parfast = [p13r/pol13dpNTvalues[i] for i, j in enumerate(pol13dpNTlabel)]
p14parfast = [p14r/pol14dpNTvalues[i] for i, j in enumerate(pol14dpNTlabel)]
p15parfast = [p15r/pol15dpNTvalues[i] for i, j in enumerate(pol15dpNTlabel)]

# %%
fig, ax = plt.subplots(figsize=(18, 20))
ax.plot(pol13dpNTlabel, p13parfast, 'r:', markersize=11, linewidth=2, marker='o')
ax.plot(pol14dpNTlabel, p14parfast, 'g:', markersize=11, linewidth=2, marker='o') 
ax.plot(pol15dpNTlabel, p15parfast, 'b:', markersize=11, linewidth=2, marker='o') 
ax.plot([0, 60],[0, 60],'k--')
ax.set_xlabel('number of cores', fontsize=label)
ax.set_ylabel('parallel acceleration', fontsize=label)
#ax.set_title('parallel speed up', fontsize=tittle)
for tick in ax.xaxis.get_major_ticks():
    tick.label.set_fontsize(tickS) 
for tick in ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(tickS)
ax.grid()
plt.legend(['pol13', 'pol14', 'pol15', 'linear'], fontsize=label)


fig.savefig("parralelFastmpi3.png")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(18, 6))
ax.plot(pol13dpNTlabel, p13efektivity, 'r:', markersize=11, linewidth=2, marker='o')
ax.plot(pol14dpNTlabel, p14efektivity, 'g:', markersize=11, linewidth=2, marker='o') 
ax.plot(pol15dpNTlabel, p15efektivity, 'b:', markersize=11, linewidth=2, marker='o') 
ax.set_xlabel('number of cores', fontsize=label)
ax.set_ylabel('effectivity', fontsize=label)
#ax.set_title('parallel effectivity', fontsize=tittle)

for tick in ax.xaxis.get_major_ticks():
    tick.label.set_fontsize(tickS) 
for tick in ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(tickS)
ax.grid()
plt.legend(['pol13', 'pol14', 'pol15'], fontsize=label)


fig.savefig("parralelEfectivitympi3.png")
plt.show()
